# %%
"""
Created by:
Nick Roseveare, Nov 2018, nicholasroseveare AT gmail.com
"""

# %% [markdown]
# ### Model Training/Tuning
#    * start with small subset of data to get everything running and then move a larger data set
#    * randomized training set using shuffle split et al. (https://scikit-learn.org/stable/modules/classes.html#module-sklearn.model_selection), want to ensure same ratio of classes in both training and test; in the case where a non-uniform (skewed class ratio) train/test data split is the only option, important to validate result with, for instance, F-1 score (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html) (take into account all entries in the confusion matrix, correct detect, correct reject, Type-I, Type-II   errors, at least for the two-class case)
#    * add parameter regularization to penalize overfitting
#    * update learning rate for longer lengths of training (reduce LR at each decade, e.g.)
#    * hyperparamter tuning via grid-search or randomized optimization
#    * NN optimization of backpropagation via Adam:  https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/, https://arxiv.org/pdf/1412.6980.pdf

# %%
import numpy as np
from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score, f1_score
import torch
import torch.utils.data
import torch.random
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim
from matplotlib import pyplot
import tqdm
import os

from eeg_project.read_data import (import_eeg_file, sample_file_list, get_all_metadata,
    my_read_eeg_generic, senlist_known, match_types, SAMP_FREQ, get_blocked_data,
    accumulate_subject_file_list, PSD_on_row_data, pass_through, zero, PSD_on_row_data, fft_on_row_data,
    eeg_half_half_alcoholic_all_subjects_obj_40, eeg_half_half_alcoholic_all_subjects_obj_100, 
    eeg_half_half_alcoholic_all_subjects_obj_tt_even_400)
from eeg_project.plot_data import plot_data_subject_dirs
from eeg_project.models import EEGNet, predict_twoclass_with_model, predict_with_model
import warnings
from sklearn.preprocessing import OneHotEncoder


metric_func_lut = dict(
    acc=accuracy_score,
    auc=roc_auc_score,
    recall=recall_score,
    precision=precision_score,
    f_1_meas=f1_score
)
PRF_metrics = ['recall', 'precision', 'f_1_meas']
basic_metrics = ['acc', 'auc']

# %% [markdown]
# In case of memory issues, can reduce batch-size to control how many samples get evaluated at one time. Ensure batch_size is a factor of length of samples so no samples are missed.

# %%
rand_data_test = False
if rand_data_test:
    #     Generate random data as an initial test

    #     Datatype - float32 (both X and Y) <br>
    #     X.shape - (#samples, 1, #timepoints,  #channels) <br>
    #     Y.shape - (#samples)
    T, C = net.T, net.C
    num_subjects = 100
    X_train = np.random.rand(num_subjects, 1, T, C).astype('float32') # np.random.rand generates between [0, 1)
    y_train = np.round(np.random.rand(num_subjects).astype('float32')) # binary data, so we round it to 0 or 1.

    X_val = np.random.rand(num_subjects, 1, T, C).astype('float32')
    y_val = np.round(np.random.rand(num_subjects).astype('float32'))

    X_test = np.random.rand(num_subjects, 1, T, C).astype('float32')
    y_test = np.round(np.random.rand(num_subjects).astype('float32'))

else:
    # if limitby, limit_mult_files, or balance_types not specified, just returned path/urls 
    # of all LARGE data set files, sample_file_list uses `get_all_metadata()` function
    file_list = sample_file_list()  
    # limitby=dict(subject='co2a0000364'), balance_types=dict('alcoholic': 2))
    
    use_onehost_categorical_feats, freq_data = True, False
    
    name_suffix = ''
    if use_onehost_categorical_feats:
        name_suffix += '.onehot_catfeats'
    if freq_data:
        name_suffix += '.fft'
        
    data_tuple = get_blocked_data(file_list,
        process_data=(fft_on_row_data if freq_data else pass_through), 
        pickle_name=f'eeg_all_data_medium_size_1200{name_suffix}.bin')

    
    if len(data_tuple) > 5:
        multi_class = True
        X_train, y_train, X_test, y_test, uses_cat_feat, classIdDict = data_tuple
    else:
        multi_class = False
        X_train, y_train, X_test, y_test, uses_cat_feat = data_tuple

dataset = torch.utils.data.TensorDataset(X_train, y_train)
# Out:
# reading binary of organized data
#
#    Xtrain:torch.Size([600, 1, 257, 64])
#    ytrain:torch.Size([600])
#    Xtest:torch.Size([600, 1, 257, 64])
#    ytest:torch.Size([600])
#    use 1-hot categorical feats: True

# %%
torch.f

# %%
ntrialsXsubjects, _, nsamps, nsen = X_train.shape

nsamps -= int(uses_cat_feat)

net = EEGNet(T=nsamps, C=nsen, 
             noutput_final=(y_train.shape[1] if multi_class else 1),
             ncat_feat=(len(match_types) if uses_cat_feat else 0))
trials_test_input = 3
print('test output', net.forward(Variable(torch.Tensor(
    np.random.rand(trials_test_input, 1, net.T+int(uses_cat_feat), net.C)))))

if multi_class:
    criterion = nn.CrossEntropyLoss()
else:
    criterion = nn.BCELoss()

# https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/
lr_start_log = -2
optimizer = optim.Adam(net.parameters(), 
                       lr=np.power(10., lr_start_log), 
                       weight_decay=0.2) #, amsgrad=True)
optimizer
# Out:
# test output tensor([[0.6192],
#         [0.7273],
#         [0.6394]], grad_fn=<SigmoidBackward>)
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.01
#     weight_decay: 0.2
# )

# %%
debug = 1
batch_size = 32
nepochs = 300
if multi_class:
    params = ["acc"]
else:
    params = ["acc", "auc", "precision", "recall", "f_1_meas"]
nparams = len(params)
train_metrics = np.zeros((nepochs, nparams), dtype=np.float)
valid_metrics = np.zeros((nepochs, nparams), dtype=np.float)
test_metrics = np.zeros((nepochs, nparams), dtype=np.float)
loss_metric = np.zeros(nepochs, dtype=np.float)

if debug == 1:
    progress_bar = tqdm.tqdm(total=nepochs, miniters=1)

learning_rate = None
break_in = [50, 30, 50]
lr = lr_start_log
learning_rate = np.ones(break_in[0]) * np.power(10., lr)

linear_change_lr = 1
learning_rate = np.concatenate([learning_rate, 
    np.flip(np.linspace(np.power(10., lr - linear_change_lr), np.power(10., lr), 
                      num=break_in[1]), axis=0)], axis=0)
lr -= linear_change_lr
linear_change_lr = 1
learning_rate = np.concatenate([learning_rate, 
    np.ones(break_in[2]) * np.power(10., lr)], axis=0)

learning_rate = np.concatenate([learning_rate, 
    np.flip(np.logspace(lr-2, lr, num=(nepochs - sum(break_in))), axis=0)])


if learning_rate is not None:
    optimizer.param_groups[0]['lr'] = learning_rate[0]

with warnings.catch_warnings(record=True) as w:
    # Cause all warnings to always be triggered.
    warnings.simplefilter("ignore")

    loader = torch.utils.data.DataLoader(dataset, batch_size=40, shuffle=True)    
    for epoch in np.arange(nepochs, dtype=int):  # loop over the dataset multiple times

        if debug > 1:
            print("\nEpoch ", epoch)

        running_loss = 0.0
        
        # more basic batching approach
#         np.random.shuffle(order)
#         for i in np.arange(len(X_train)//batch_size-1, dtype=int):
#             s = i*batch_size
#             e = i*batch_size+batch_size
#             if isinstance(X_train, torch.Tensor):
#                 train_inputs = X_train[order[s:e]]
#                 train_labels = torch.FloatTensor(np.array(y_train[order[s:e]].numpy()).T * 1.0)
#             else:
#                 train_inputs = torch.from_numpy(X_train[order[s:e]])
#                 train_labels = torch.FloatTensor(np.array([y_train[order[s:e]]]).T * 1.0)
#             # wrap them in Variable
#             train_inputs, train_labels = Variable(train_inputs), Variable(train_labels)

        # use the 'loader' object for batching (shuffling)
        for train_inputs, train_labels in loader:

            # zero the parameter gradients
            optimizer.zero_grad()
            
            train_inputs, train_labels = Variable(train_inputs), Variable(
                torch.FloatTensor(np.array(train_labels.numpy()).T * 1.0))

            # forward + backward + optimize
            outputs = net(train_inputs)
            if multi_class:
                loss = criterion(outputs, Variable((torch.max(train_labels, 1))[1]))
            else:
                loss = criterion(outputs, train_labels)
            loss.backward()


            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(train_inputs)
            loss = criterion(outputs, train_labels)
            loss.backward()


            optimizer.step()

            running_loss += loss.data[0]

        loss_metric[epoch] = running_loss
        
        if learning_rate is not None:
            optimizer.param_groups[0]['lr'] = learning_rate[epoch]

        
        # Validation accuracy
        train_metrics[epoch, :] = predict_with_model(net, X_train, y_train, params, debug=debug)
    #     valid_metrics[epoch, :] = predict_twoclass_with_model(net, X_val, y_val, params, debug=debug)
        test_metrics[epoch, :] = predict_with_model(net, X_test, y_test, params, debug=debug)

        if debug == 1:
            progress_bar.n = epoch + 1
            progress_bar.set_description(f'loss:{running_loss:.3g}, acc:[' 
                f'{train_metrics[epoch, 0]:.2f}|{test_metrics[epoch, 0]:.2f}] ')

        if debug > 1:
            print(params)
            print("Training Loss ", running_loss)
            print("Train      - ", train_metrics[epoch, :])
    #         print("Validation - ", valid_metrics[epoch, :])
            print("Test       - ", test_metrics[epoch, :])
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-250b0416706f> in <module>()
#      99         train_metrics[epoch, :] = predict_twoclass_with_model(net, X_train, y_train, params, debug=debug)
#     100     #     valid_metrics[epoch, :] = predict_twoclass_with_model(net, X_val, y_val, params, debug=debug)
# --> 101         test_metrics[epoch, :] = predict_twoclass_with_model(net, X_test, y_test, params, debug=debug)
#     102
#     103         if debug == 1:
#
# ~/Documents/Work/Projects/Interview_problems/TruU/eeg_ML/eeg_project/models.py in predict_twoclass_with_model(model, X, Y, params, debug)
#      91                 inputs = Variable(torch.from_numpy(X[s:e]))
#      92
# ---> 93             pred = model(inputs)
#      94             predicted.extend(pred.data.cpu().numpy().tolist())
#      95
#
# ...

# %%
(train_metrics[:, 0] == train_metrics[:, 1]).sum(), train_metrics.shape
# Out:
# (126, (300, 5))

# %%
# plot loss and other metrics 
# could use: sklearn.model_selection.learning_curve, but this allows less direct control on train/test set split

pyplot.figure(figsize=(10, 5))
lg, = pyplot.plot(loss_metric)
# if learning_rate is not None:
#     lg, = pyplot.plot(learning_rate)
pyplot.title('Loss')
pyplot.xlabel('Epoch')
pyplot.yscale('log')
pyplot.show()    

for prm in basic_metrics:
    if prm in params:
        leg = []
        pyplot.figure(figsize=(10, 5))
        print(prm, params.index(prm))
        lg, = pyplot.plot(train_metrics[:, params.index(prm)], label=('train'))
        leg.append(lg)
        lg, = pyplot.plot(test_metrics[:, params.index(prm)], label=('test'))    
        leg.append(lg)

        pyplot.legend(handles=leg)
        pyplot.title(prm)
        pyplot.xlabel('Epoch')
        pyplot.show()

has_prf =  any([(prm in PRF_metrics) for prm in params])

if has_prf:
    pyplot.figure(figsize=(10, 5))
    leg = []
    for prm in PRF_metrics: 
        if prm in params:
            lg, = pyplot.plot(train_metrics[:, params.index(prm)], label=(prm + ':train'))
            leg.append(lg)
    
    for prm in PRF_metrics: 
        if prm in params:
            lg, = pyplot.plot(test_metrics[:, params.index(prm)], label=(prm + ':test'))    
            leg.append(lg)

    pyplot.legend(handles=leg)
    pyplot.title('Precision / Recall')
    pyplot.xlabel('Epoch')
    pyplot.show()
# Out:
# acc 0
# auc 1

# %%
# data_dir = 'small_data_set'
# data_dirs = [f'./{data_dir}/SMNI_CMI_TRAIN', f'./{data_dir}/SMNI_CMI_TEST']

# file_list, unq_items, total = accumulate_subject_file_list(data_dirs, limitby=dict(match='obj'),
#         limit_mult_files=(400, [('subject', 20), ('alcoholic', 2), ('is_test_set', 2)]), df_type='wide', 
#         debug=1)
# unq_items, file_list

# %%
sklearn.utils.check_consistent_length?
